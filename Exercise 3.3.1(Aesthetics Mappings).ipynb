# %%
library(tidyverse)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.1.0     v purrr   0.2.5
# v tibble  1.4.2     v dplyr   0.7.7
# v tidyr   0.8.2     v stringr 1.3.1
# v readr   1.1.1     v forcats 0.3.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %% [markdown]
# **1. What’s gone wrong with this code? Why are the points not blue?**

# %%
ggplot(data = mpg)+
    geom_point(mapping = aes(x = displ, y = hwy, color = "blue"))
# Out:
# plot without title

# %% [markdown]
# _What's wrong with the code:The color aesthetic has not been set manually as an argument to the geom function,i.e it should go outside the aesthetics attributes aes().
# Why are the points not blue:This only changes the appearance of the plot and conveys no information the dataset containing the variables of interest._

# %% [markdown]
# _Correction: Manually set the color aesthetic outside aes() as an argument to the geom function (geom_point())_

# %%
ggplot(data = mpg)+
    geom_point(mapping = aes(x = displ, y = hwy), color = "blue")
# Out:
# plot without title

# %% [markdown]
# **2. Which variables in mpg are categorical? Which variables are continuous? (Hint: type ?mpg to read the documentation for the dataset.) How can you see this information when you run mpg?**

# %%
?mpg
# Out:
# mpg                  package:ggplot2                   R Documentation
#
# r
#
# n:
#
#      This dataset contains a subset of the fuel economy data that the
#      EPA makes available on <URL: http://fueleconomy.gov>. It contains
#      only models which had a new release every year between 1999 and
#      2008 - this was used as a proxy for the popularity of the car.
#
# e:
#
#      mpg
#
# t:
#
#      A data frame with 234 rows and 11 variables
#
#      manufacturer
#
#      model model name
#
#      displ engine displacement, in litres
#
#      year year of manufacture
#
#      cyl number of cylinders
#
#      trans type of transmission
#
#      drv f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#      cty city miles per gallon
#
#      hwy highway miles per gallon
#
#      fl fuel type
#
#      class "type" of car

# %%
mpg
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# ...

# %% [markdown]
# _So when mpg is run on R studio it shows the variable types below the variables. On Jupyter notebooks this doesn't show and a function has to be used. Here str()_

# %%
library("IRdisplay")
display_png(file="C:\\Users\\ME\\Documents\\Rstudiovariabletype.png")

# %%
str(mpg)
# Out:
# Classes 'tbl_df', 'tbl' and 'data.frame':	234 obs. of  11 variables:
#  $ manufacturer: chr  "audi" "audi" "audi" "audi" ...
#  $ model       : chr  "a4" "a4" "a4" "a4" ...
#  $ displ       : num  1.8 1.8 2 2 2.8 2.8 3.1 1.8 1.8 2 ...
#  $ year        : int  1999 1999 2008 2008 1999 1999 2008 1999 1999 2008 ...
#  $ cyl         : int  4 4 4 4 6 6 6 4 4 4 ...
#  $ trans       : chr  "auto(l5)" "manual(m5)" "manual(m6)" "auto(av)" ...
#  $ drv         : chr  "f" "f" "f" "f" ...
#  $ cty         : int  18 21 20 21 16 18 18 18 16 20 ...
#  $ hwy         : int  29 29 31 30 26 26 27 26 25 28 ...
#  $ fl          : chr  "p" "p" "p" "p" ...
#  $ class       : chr  "compact" "compact" "compact" "compact" ...

# %% [markdown]
# Below each variable column name a variable type is provided. <chr> for characters which are categorical and <dbl> for double and <int> for integers which are continous.so:
#
# 1 Categorical:
#    * Manufacturer
#    * Model
#    * trans
#    * drv
#    * fl
#    * class
#
# 2 Continous:
#    * displ
#    * year
#    * cyl
#    * cty
#    * hwy

# %% [markdown]
# **3. Map a continuous variable to color, size, and shape. How do these aesthetics behave differently for categorical versus continuous variables?**

# %%
ggplot(data = mpg)+
    geom_point(mapping = aes(x = displ, y = hwy, color = cty))
# Out:
# plot without title

# %% [markdown]
# _Ggplot when mapping a continous variable with color aesthetic creates a scale that varies from light(here light blue) to dark(here dark blue). The data points get darker as the city miles per gallon increments and lighter as it decrements._

# %%
ggplot(data = mpg)+
    geom_point(mapping = aes(x = displ, y = hwy, size = cyl))
# Out:
# plot without title

# %% [markdown]
# _Ggplot when mapping a continous variable with size aesthetic creates a scale of circles that varies from small to large. The data points get larger as the number of cylinders increments and smaller as it decrements._

# %%
ggplot(data = mpg)+
    geom_point(mapping = aes(x = displ, y = hwy, shape = year))
# Out:
# ERROR while rich displaying an object: Error: A continuous variable can not be mapped to shape
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# ...

# %% [markdown]
# _Color can vary on a scale so can size and thus can represent varying continous variables in scale. Shapestake distinct unvarying forms thus are categorical and thus can not represent continous variables and but represent categorical variables. Hence the error._

# %% [markdown]
# *4. What happens if you map the same variable to multiple aesthetics?**

# %%
ggplot(data = mpg)+
    geom_point(mapping = aes(x = displ, y = hwy, color = displ, size = displ))
# Out:
# plot without title

# %% [markdown]
# _So when you map the same continous variable all the aesthetics argued are mapped and different legends made for them._

# %%
ggplot(data = mpg)+
    geom_point(mapping = aes(x = displ, y = hwy, color = fl, shape = fl))
# Out:
# plot without title

# %% [markdown]
# _So when you map the same continous variable all the aesthetics argued are mapped and a single legend made for them._

# %% [markdown]
# **5. What does the stroke aesthetic do? What shapes does it work with? (Hint: use ?geom_point.)**

# %%
?geom_point
# Out:
# geom_point               package:ggplot2               R Documentation
#
# s
#
# n:
#
#      The point geom is used to create scatterplots. The scatterplot is
#      most useful for displaying the relationship between two continuous
#      variables. It can be used to compare one continuous and one
#      categorical variable, or two categorical variables, but a
#      variation like 'geom_jitter()', 'geom_count()', or 'geom_bin2d()'
#      is usually more appropriate. A _bubblechart_ is a scatterplot with
#      a third variable mapped to the size of points.
#
# e:
#
#      geom_point(mapping = NULL, data = NULL, stat = "identity",
#        position = "identity", ..., na.rm = FALSE, show.legend = NA,
#        inherit.aes = TRUE)
#
# s:
#
#  mapping: Set of aesthetic mappings created by 'aes()' or 'aes_()'. If
#           specified and 'inherit.aes = TRUE' (the default), it is
#           combined with the default mapping at the top level of the
# ...

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy), shape = 21,
             fill = 'red', size = 5, stroke = 5, color = 'white')
# Out:
# plot without title

# %% [markdown]
# _Stroke controls the width of the border. It works with the 25 built-in R shapes that are identified by number (0 - 20) to represent diffrent shape forms._

# %% [markdown]
# **6. What happens if you map an aesthetic to something other than a variable name, like aes(color = displ < 5)?**

# %%
ggplot(data = mpg)+
    geom_point(mapping = aes(x = displ, y = hwy, color = displ < 5))
# Out:
# plot without title

# %% [markdown]
# _ggplot checks if logically displ<5 and creates a boolean value that indicates if this expression is TRUE(if less than 5) or FALSE(if not less than 5) that taken on different colors._
