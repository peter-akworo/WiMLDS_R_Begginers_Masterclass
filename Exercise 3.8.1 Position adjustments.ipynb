# %%
library("tidyverse")
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.2.1     v purrr   0.3.3
# v tibble  2.1.3     v dplyr   0.8.3
# v tidyr   1.0.0     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.4.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %% [markdown]
# **1. What is the problem with this plot? How could you improve it?**

# %%
ggplot(data = mpg, mapping = aes(x = cty, y = hwy)) +
    geom_point()
# Out:
# plot without title

# %% [markdown]
# _There is overlapping of data points because there are multiple observations for value combinations of hwy and cty_

# %% [markdown]
# _We can improve the plot using a jitter position adjustment_

# %%
ggplot(data = mpg, mapping = aes(x = cty, y = hwy)) +
    geom_point(position = "jitter")
# Out:
# plot without title

# %% [markdown]
# _*Or use the `geom_jitter()` instead of `geom_point()`*

# %%
ggplot(data = mpg, mapping = aes(x = cty, y = hwy)) +
    geom_jitter()
# Out:
# plot without title

# %% [markdown]
# **2. What parameters to geom_jitter() control the amount of jittering?**

# %%
?geom_jitter()
# Out:
# geom_jitter              package:ggplot2               R Documentation
#
# s
#
# n:
#
#      The jitter geom is a convenient shortcut for 'geom_point(position
#      = "jitter")'. It adds a small amount of random variation to the
#      location of each point, and is a useful way of handling
#      overplotting caused by discreteness in smaller datasets.
#
# e:
#
#      geom_jitter(mapping = NULL, data = NULL, stat = "identity",
#        position = "jitter", ..., width = NULL, height = NULL,
#        na.rm = FALSE, show.legend = NA, inherit.aes = TRUE)
#
# s:
#
#  mapping: Set of aesthetic mappings created by 'aes()' or 'aes_()'. If
#           specified and 'inherit.aes = TRUE' (the default), it is
#           combined with the default mapping at the top level of the
#           plot. You must supply 'mapping' if there is no plot mapping.
#
#     data: The data to be displayed in this layer. There are three
#           options:
#
# ...

# %% [markdown]
# *The parameters `width` and `height` control the amount of jittering in a `geom_jitter()` plot*

# %%
ggplot(data = mpg, mapping = aes(x = cty, y = hwy)) +
    geom_jitter(width = 0, height = 0)
# Out:
# plot without title

# %% [markdown]
# _On default_ 👆

# %% [markdown]
# _`Width` and `height` parameters set_ 👇

# %%
ggplot(data = mpg, mapping = aes(x = cty, y = hwy)) +
    geom_jitter(width = 5, height = 10)
# Out:
# plot without title

# %% [markdown]
# **3. Compare and contrast geom_jitter() with geom_count()**

# %% [markdown]
# _`geom_jitter()` randomly variates the data points across the plot to avoid overlapping. This comes at a cost of statistical accuracy.
# `geom_count()` sizes the data points relative to the frequency of the observations_

# %%
ggplot(data = mpg, mapping = aes(x = cty, y = hwy)) +
    geom_jitter()
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = cty, y = hwy)) +
    geom_count()
# Out:
# plot without title

# %% [markdown]
# **4. What’s the default position adjustment for geom_boxplot()?
# Create a visualization of the mpg dataset that demonstrates it.**

# %%
?geom_boxplot()
# Out:
# geom_boxplot              package:ggplot2              R Documentation
#
# y)
#
# n:
#
#      The boxplot compactly displays the distribution of a continuous
#      variable. It visualises five summary statistics (the median, two
#      hinges and two whiskers), and all "outlying" points individually.
#
# e:
#
#      geom_boxplot(mapping = NULL, data = NULL, stat = "boxplot",
#        position = "dodge2", ..., outlier.colour = NULL,
#        outlier.color = NULL, outlier.fill = NULL, outlier.shape = 19,
#        outlier.size = 1.5, outlier.stroke = 0.5, outlier.alpha = NULL,
#        notch = FALSE, notchwidth = 0.5, varwidth = FALSE, na.rm = FALSE,
#        show.legend = NA, inherit.aes = TRUE)
#
#      stat_boxplot(mapping = NULL, data = NULL, geom = "boxplot",
#        position = "dodge2", ..., coef = 1.5, na.rm = FALSE,
#        show.legend = NA, inherit.aes = TRUE)
#
# s:
#
#  mapping: Set of aesthetic mappings created by 'aes()' or 'aes_()'. If
# ...

# %% [markdown]
# _The default position adjustment for `geom_boxplot` is `dodge2` aka `position_dodge` that does not change the vertical position of the plots but moves them horizontally to avoid overlapping_

# %%
ggplot(data = mpg)+
    geom_boxplot(mapping = aes(x = drv, y = hwy, color = class))
# Out:
# plot without title
